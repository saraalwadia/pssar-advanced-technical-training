# %%
import pandas as pd

df = pd.read_csv("../data/raw/attacks.csv", encoding="latin1")

# %%
print("Raw shape:", df.shape)

print("After removing blank rows:", df.dropna(how="all").shape)
# Out:
# Raw shape: (25614, 22)
# After removing blank rows: (6096, 22)

# %%
# What are the raw shape and true data shape after removing blank rows?
df.shape
df.dropna(how="all").shape
# Out:
# (6096, 22)

# %%
# Which 2 column names have trailing whitespace?
df.columns.tolist()
[col for col in df.columns if col != col.strip()]
# Out:
# ['Sex ', 'Species ']

# %%
# What % of Age values are missing? What % of Time?
df["Age"].isnull().mean() * 100
df["Time"].isnull().mean() * 100
# Out:
# np.float64(88.8810806590146)

# %%
print("Age missing %:", df["Age"].isnull().mean() * 100)
print("Time missing %:", df["Time"].isnull().mean() * 100)
# Out:
# Age missing %: 86.82751620207699
# Time missing %: 88.8810806590146

# %%
# How many distinct values does Fatal (Y/N) have? What's wrong with it?
df["Fatal (Y/N)"].value_counts(dropna=False)
# Out:
# Fatal (Y/N)
# NaN        19550
# N           4391
# Y           1566
# UNKNOWN       94
#  N             8
# 2017           1
# F              1
# N              1
# #VALUE!        1
# n              1
# Name: count, dtype: int64

# %%
# Observation (write in markdown cell):
# Problem: inconsistent values like 'NaN', 'Y ', 'N', 'UNKNOWN', ' N', '2017', '#VALUE!', 'n'.

# %%
metadata_cols = [col for col in df.columns if "href" in col.lower() or "pdf" in col.lower()]

# Name 2 columns that are pure metadata and should be dropped
df.columns
# pdf, href formula
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='str')

# %%
df.head()
# Out:
#     Case Number                  Date    Year        Type         Country  \
# 0    2017.06.11            2017-06-11  2017.0  Unprovoked       AUSTRALIA
# 1  2017.06.10.b            2017-06-10  2017.0  Unprovoked       AUSTRALIA
# 2  2017.06.10.a            2017-06-10  2017.0  Unprovoked             USA
# 3  2017.06.07.R  Reported 07-Jun-2017  2017.0  Unprovoked  UNITED KINGDOM
# 4    2017.06.04            2017-06-04  2017.0  Unprovoked             USA
#
#                 Area                                         Location  \
# 0  Western Australia                         Point Casuarina, Bunbury
# 1           Victoria                    Flinders, Mornington Penisula
# 2            Florida                      Ponce Inlet, Volusia County
# 3        South Devon                                    Bantham Beach
# 4            Florida  Middle Sambo Reef off Boca Chica, Monroe County
#
#         Activity            Name Sex   ... Fatal (Y/N)   Time  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 25614 entries, 0 to 25613
# Data columns (total 22 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6095 non-null   str
#  1   Date                    6094 non-null   str
#  2   Year                    6092 non-null   float64
#  3   Type                    6090 non-null   str
#  4   Country                 6048 non-null   str
#  5   Area                    5682 non-null   str
#  6   Location                5583 non-null   str
#  7   Activity                5559 non-null   str
#  8   Name                    5888 non-null   str
#  9   Sex                     5517 non-null   str
#  10  Age                     3374 non-null   str
#  11  Injury                  6066 non-null   str
#  12  Fatal (Y/N)             6064 non-null   str
#  13  Time                    2848 non-null   str
#  14  Species                 3100 non-null   str
# ...
